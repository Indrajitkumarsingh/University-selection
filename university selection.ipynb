# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
my_data=pd.read_csv("Admission_Predict.csv")
my_data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# 0           1             0.92
# 1           1             0.76
# 2           1             0.72
# 3           1             0.80
# 4           0             0.65
# ..        ...              ...
# 495         1             0.87
# 496         1             0.96
# 497         1             0.93
# 498         0             0.73
# 499         0             0.84
#
# [500 rows x 9 columns]

# %%
my_data.isna().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
my_data.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000        500.00000
# mean     3.48400    8.576440    0.560000          0.72174
# std      0.92545    0.604813    0.496884          0.14114
# min      1.00000    6.800000    0.000000          0.34000
# 25%      3.00000    8.127500    0.000000          0.63000
# 50%      3.50000    8.560000    1.000000          0.72000
# 75%      4.00000    9.040000    1.000000          0.82000
# max      5.00000    9.920000    1.000000          0.97000

# %%
my_data["GRE Score"].plot.box()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
my_data.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit'],
#       dtype='object')

# %%
def box_plot(col):
    plt.figure()
    my_data[col].plot(kind="box")
    plt.title(f"Box plot of {col}")
    plt.ylabel("values")
    plt.grid(True)
    plt.tight_layout()

# %%
for col in my_data.columns:
    box_plot(col)

# %%
plt.figure(figsize=(10,10))
my_data["TOEFL Score"].plot(kind="box")
plt.title(f"Box plot of TOEFL score")
plt.ylabel("values")
plt.grid(True)
plt.tight_layout()

# %%
my_data["University Rating"].value_counts().plot(kind="bar")
plt.ylabel("values")
plt.title(f"Box plot University Rating")
plt.tight_layout()
plt.grid()
plt.show()

# %%
my_data.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit'],
#       dtype='object')

# %%
def bar_plot(col):
    plt.figure()
    my_data[col].value_counts().plot(kind="bar",rot=90)
    plt.title(f"Bar plot of {col}")
    plt.xticks(fontsize=10)
    #plt.xlabel(col)
    plt.ylabel("values")
    plt.grid(True)
    plt.tight_layout()

# %%
for col in['GRE Score', 'TOEFL Score', 'University Rating', 'SOP','LOR ', 'Research', 'Chance of Admit']:
    bar_plot(col)

# %%
def line_plot(col):
    plt.figure()
    my_data[col].value_counts().plot(kind="line",rot=90)
    plt.title(f"line plot of {col}")
    plt.xticks(fontsize=10)
    #plt.xlabel(col)
    plt.ylabel("values")
    plt.grid(True)
    plt.tight_layout()

# %%
for col in['GRE Score', 'TOEFL Score', 'University Rating', 'SOP','LOR ', 'Research', 'Chance of Admit']:
    line_plot(col)

# %%
y=my_data["Chance of Admit"]
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit, Length: 500, dtype: float64

# %%
x=my_data.drop(["Serial No.","Chance of Admit"],axis=1)
x
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
# [500 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=12345,shuffle=True)
print(f"x_train {x_train.shape}")
print(f"x_test {y_test.shape}")
print(f"y_train {x_train.shape}")
print(f"y_test {y_test.shape}")
# Out:
# x_train (375, 7)
# x_test (125,)
# y_train (375, 7)
# y_test (125,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model_lr=LinearRegression()
model_lr
# Out:
# LinearRegression()

# %%
model_lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model_lr.predict(x_test)
y_pred
# Out:
# array([0.46747059, 0.7043113 , 0.52008333, 0.74113125, 0.71212995,
#        0.80968438, 0.70842694, 0.91010864, 0.6628263 , 0.71276975,
#        0.87306685, 0.61649745, 0.79162591, 0.87751638, 0.51359588,
#        0.952002  , 0.60720274, 0.8372675 , 0.73063946, 0.66811838,
#        0.417752  , 0.95979996, 0.5733307 , 0.78932568, 0.85283291,
#        0.94529043, 0.64644657, 0.7394248 , 0.68939497, 0.65411306,
#        0.54811385, 0.71604359, 0.82898346, 0.93917809, 0.8686401 ,
#        0.67507883, 0.99798533, 0.52153907, 0.83700555, 0.53382617,
#        0.63586088, 0.60456203, 0.68990108, 0.76509947, 0.91354168,
#        0.58163047, 0.78955587, 0.63446231, 0.91075092, 0.72635878,
#        0.80513161, 0.45854501, 0.73267841, 0.64810875, 0.71834853,
#        0.65620164, 0.88345771, 0.9031338 , 0.57787433, 0.67385742,
#        0.76931238, 0.60420352, 0.50341024, 0.79612877, 0.64078567,
#        0.81125366, 0.64290368, 0.78193113, 0.80754843, 0.84496093,
#        0.86327347, 0.75801761, 0.61870212, 0.84555219, 0.61710023,
#        0.9551592 , 0.51946574, 0.60535294, 0.7075425 , 0.88649462,
#        0.76221943, 0.70528637, 0.64739286, 0.72072686, 0.62140635,
#        0.71423109, 0.64851464, 0.60999508, 0.95055004, 0.96652771,
#        0.74875402, 0.52937142, 0.74705275, 0.74406322, 0.78764569,
#        0.69359136, 0.58042155, 0.99472619, 0.65467693, 0.825624  ,
#        0.68551549, 0.8817818 , 0.62828851, 0.56660609, 0.65132667,
#        0.97283848, 0.63389024, 0.83274681, 0.8999957 , 0.59796136,
#        0.93266025, 0.65651914, 0.71302566, 0.85930418, 0.56442452,
#        0.63529897, 0.61044646, 0.90607837, 0.68172569, 0.65258407,
#        0.61269546, 0.64893413, 0.58060092, 0.71803025, 0.91403044])

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
mse=mean_squared_error(y_test,y_pred)
print(f"Mean square error is {mse}")
rmse=sqrt(mse)
print(f"Root mean squared error is {rmse}")
# Out:
# Mean square error is 0.0037572693343877303
# Root mean squared error is 0.06129656869995033

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.metrics import r2_score

# %%
select_models=[LinearRegression(),
             DecisionTreeRegressor(max_depth=None,min_samples_leaf=2,min_samples_split=5),
             RandomForestRegressor(max_depth=None,min_samples_leaf=2,min_samples_split=5,n_estimators=100)]

# %%
my_rmse=[]
my_r_square=[]
adj_r2_square_value=[]
for model in select_models:
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    rmse=sqrt(mean_squared_error(y_pred,y_test))
    my_rmse.append(rmse)
    r_sq=r2_score(y_pred,y_test)
    my_r_square.append(r_sq)
    print(f"RMSE value {my_rmse} and R Squared value {my_r_square} of model{model}")
    print(f"List of Rmse {my_rmse}")
    print("--------------------")
    print(f"List of R square {my_r_square}")
    adj_r_square_test= 1 -(1-r_sq)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
    print(f"{model},adj_r_square_test")
    adj_r2_square_value.append(adj_r_square_test)
    print(f"Adjusted R Square {adj_r2_square_value} of model {model}")
    print("----------------")
    print(f"Adjusted R Square {adj_r2_square_value}")
# Out:
# RMSE value [0.06129656869995033] and R Squared value [0.7867516752498763] of modelLinearRegression()
# List of Rmse [0.06129656869995033]
# --------------------
# List of R square [0.7867516752498763]
# LinearRegression(),adj_r_square_test
# Adjusted R Square [0.7739932284699544] of model LinearRegression()
# ----------------
# Adjusted R Square [0.7739932284699544]
# RMSE value [0.06129656869995033, 0.0851334573217578] and R Squared value [0.7867516752498763, 0.6552856194102152] of modelDecisionTreeRegressor(min_samples_leaf=2, min_samples_split=5)
# List of Rmse [0.06129656869995033, 0.0851334573217578]
# --------------------
# List of R square [0.7867516752498763, 0.6552856194102152]
# DecisionTreeRegressor(min_samples_leaf=2, min_samples_split=5),adj_r_square_test
# Adjusted R Square [0.7739932284699544, 0.6346616821099718] of model DecisionTreeRegressor(min_samples_leaf=2, min_samples_split=5)
# ----------------
# Adjusted R Square [0.7739932284699544, 0.6346616821099718]
# RMSE value [0.06129656869995033, 0.0851334573217578, 0.06556375623679084] and R Squared value [0.7867516752498763, 0.6552856194102152, 0.7562893010545407] of modelRandomForestRegressor(min_samples_leaf=2, min_samples_split=5)
# List of Rmse [0.06129656869995033, 0.0851334573217578, 0.06556375623679084]
# --------------------
# List of R square [0.7867516752498763, 0.6552856194102152, 0.7562893010545407]
# RandomForestRegressor(min_samples_leaf=2, min_samples_split=5),adj_r_square_test
# Adjusted R Square [0.7739932284699544, 0.6346616821099718, 0.7417083190663509] of model RandomForestRegressor(min_samples_leaf=2, min_samples_split=5)
# ----------------
# Adjusted R Square [0.7739932284699544, 0.6346616821099718, 0.7417083190663509]

# %%
result=[my_rmse,my_r_square,adj_r2_square_value]
result
# Out:
# [[0.06129656869995033, 0.0851334573217578, 0.06556375623679084],
#  [0.7867516752498763, 0.6552856194102152, 0.7562893010545407],
#  [0.7739932284699544, 0.6346616821099718, 0.7417083190663509]]

# %%
a=pd.DataFrame(data=result,columns=["LR","DTR","RF"],index=["rmse","R square","Adjusted R Square"])
a
# Out:
#                          LR       DTR        RF
# rmse               0.061297  0.085133  0.065564
# R square           0.786752  0.655286  0.756289
# Adjusted R Square  0.773993  0.634662  0.741708

# %%
a.LR.plot(kind='bar')
plt.title('LinearRegression Model Performance Parameters')
plt.ylabel('Values')
plt.show()

# %%
a.DTR.plot(kind='bar')
plt.title('DecisionTreeRegressor Model Performance Parameters')
plt.ylabel('Values')
plt.show()

# %%
a.RF.plot(kind='bar')
plt.title('RandomForestRegressor Model Performance Parameters')
plt.ylabel('Values')
plt.show()

# %%
def my_model_plot(col):
    plt.figure()
    a[col].plot(kind="bar")
    plt.title(f"Model Performance Graph {col}")
    plt.ylabel("Values")
    plt.grid(True)
    plt.tight_layout()

# %%
for col in a.columns:
    my_model_plot(col)

# %%
rf=RandomForestRegressor(max_depth=None,min_samples_leaf=2,min_samples_split=5,n_estimators=100)

# %%
rf.fit(x_train,y_train)
rf.predict(x_test)
# Out:
# array([0.45548516, 0.68320868, 0.48625913, 0.74690395, 0.66987206,
#        0.78867401, 0.69827183, 0.91944615, 0.6851088 , 0.71667393,
#        0.89358508, 0.60768702, 0.76770409, 0.89315131, 0.48353031,
#        0.93410468, 0.56630004, 0.82977417, 0.74465056, 0.69010413,
#        0.45008671, 0.9415248 , 0.52762937, 0.77004405, 0.80157028,
#        0.93165881, 0.64371978, 0.75794298, 0.69919821, 0.65416853,
#        0.53869226, 0.74102595, 0.85888095, 0.92889476, 0.89276556,
#        0.68297133, 0.95264816, 0.55203893, 0.81810504, 0.52750294,
#        0.67311758, 0.60502482, 0.69316873, 0.69445512, 0.93135488,
#        0.55784434, 0.78886665, 0.66993767, 0.92298702, 0.74328278,
#        0.7713821 , 0.46422532, 0.74901432, 0.65806262, 0.71306472,
#        0.66889671, 0.90643313, 0.9113725 , 0.55997274, 0.65070603,
#        0.74785542, 0.62556595, 0.52496246, 0.80782913, 0.6462992 ,
#        0.79921651, 0.63849193, 0.76053591, 0.78187766, 0.85084956,
#        0.89212171, 0.77892175, 0.66659926, 0.83351574, 0.61936607,
#        0.94680423, 0.44051992, 0.63217569, 0.68868056, 0.91846909,
#        0.74189984, 0.71157253, 0.65171109, 0.70471996, 0.67490806,
#        0.74652706, 0.68412566, 0.65274488, 0.93003671, 0.94670661,
#        0.74727488, 0.56315675, 0.71019825, 0.73319947, 0.80145   ,
#        0.68403642, 0.59889544, 0.95643483, 0.67346679, 0.82269079,
#        0.69526637, 0.8963406 , 0.628085  , 0.49584556, 0.65851496,
#        0.9544903 , 0.61930452, 0.8234873 , 0.90152401, 0.61071442,
#        0.92323607, 0.6905465 , 0.7188104 , 0.88417948, 0.61206629,
#        0.61975206, 0.61799623, 0.9120271 , 0.6942819 , 0.68176754,
#        0.63015119, 0.65629683, 0.55751909, 0.7172744 , 0.91397587])

# %%
import pickle
pickle.dump(rf,open("case_study_university.pkl","wb"))

# %%
x_test.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research'],
#       dtype='object')
